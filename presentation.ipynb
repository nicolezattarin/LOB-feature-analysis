# %%
from IPython.display import Image
Image("figures/LOB.png", width=600)

# %%
Image("figures/OFI_ex1.png", width=800)

# %%
Image("figures/OFI_ex2.png", width=800)

# %%
Image("figures/OFI_levels_fit.png", width=1000)
